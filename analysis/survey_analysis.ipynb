# %%
import pandas as pd
import numpy as np
import csv
from scipy import stats
from pandas import json_normalize
import json

# %%
survey_before_efficacy = pd.read_csv('survey_before_efficacy.csv', encoding='utf-8')
survey_after_efficacy = pd.read_csv('survey_after_efficacy.csv', encoding='utf-8')
survey_baseline = pd.read_csv('survey_baseline.csv', encoding='utf-8')
survey_intervention = pd.read_csv('survey_intervention.csv', encoding='utf-8')

survey_before_efficacy = survey_before_efficacy.drop('타임스탬프', axis=1)
survey_after_efficacy = survey_after_efficacy.drop('타임스탬프', axis=1)
survey_after_efficacy = survey_after_efficacy.drop('주민등록번호(예 980731-1OOOOOO)', axis=1)
survey_after_efficacy = survey_after_efficacy.drop('주소', axis=1)
survey_after_efficacy = survey_after_efficacy.drop('계좌번호(예 우리은행 1002-OOO-OOOOOO)', axis=1)
survey_baseline = survey_baseline.drop('타임스탬프', axis=1)
survey_intervention = survey_intervention.drop('타임스탬프', axis=1)

survey_baseline.columns
# Out:
# Index(['참가자 번호', '해당 시스템을 통해 아이디어를 피드백 하는 것이 재미있었다. ',
#        '해당 시스템을 통해 아이디어를 피드백 하는 것은 쉬웠다.', '앞으로도 해당 시스템을 통해 피드백을 연습하고 싶다.',
#        '해당 시스템의 사용하여 피드백 하는 것은 많은 인지부하(cognitive load)를 필요로 했다.',
#        '해당 시스템을 통해 디자인 아이디어의 피드백을 주는 것이 실제 디자인 아이디어의 피드백을 주는 경험과 유사하다.',
#        '해당 시스템의 학생(멘티)은 실제 디자인과 학생 같았다.',
#        '해당 시스템에서 학생(멘티)와의 대화가 기존에 생각지 못한 피드백을 떠올리도록 영감을 주었다.',
#        '해당 시스템이 내가 피드백을 잘 제공하고 있는지 인지하는데 도움이 되었다.',
#        '나의 피드백을 통해 학생(멘티)의 아이디어가 개선되었다.', '해당 시스템을 사용하고 나의 피드백 제공 실력이 향상되었다.'],
#       dtype='object')

# %%
survey_before_efficacy_mean_value_1 = survey_before_efficacy['1. 피드백 수용자의 수준을 파악하기 위한 다양한 평가 전략을 사용할 수 있다.'].mean()
survey_before_efficacy_mean_value_2 = survey_before_efficacy['2. 피드백 수용자가 혼란스러워할 때 대체 설명이나 예시를 제공할 수 있다.'].mean()
survey_before_efficacy_mean_value_3 = survey_before_efficacy['3. 피드백 수용자를 위한 좋은 질문을 만들 수 있다.'].mean()
survey_before_efficacy_mean_value_5 = survey_before_efficacy['5. 피드백 수용자의 어려운 질문에 잘 대처 할 수 있다.'].mean()
survey_before_efficacy_mean_value_6 = survey_before_efficacy['6. 피드백 수용자의 수준에 맞게 피드백을 조정할 수 있다.'].mean()
survey_before_efficacy_mean_value_7 = survey_before_efficacy['7. 피드백 수용자가 나의 피드백을 얼마나 이해했는지 파악할 수 있다.'].mean()
survey_before_efficacy_mean_value_8 = survey_before_efficacy['8. 능력이 뛰어난 피드백 수용자에게 적절한 피드백을 제공할 수 있다.'].mean()
survey_before_efficacy_mean_value_17 = survey_before_efficacy['17. 피드백 수용자가 디자인 잘할 수 있다고 믿게 하기 위해 노력할 수 있다.'].mean()
survey_before_efficacy_mean_value_18 = survey_before_efficacy['18. 피드백 수용자가 디자인에 가치를 두도록 도울 수 있다.'].mean()
survey_before_efficacy_mean_value_19 = survey_before_efficacy['19. 디자인에 흥미를 보이지 않는 피드백 수용자에게 동기를 부여할 수 있다.'].mean()
survey_before_efficacy_mean_value_22 = survey_before_efficacy['22. 피드백 수용자가 비판적으로 사고하도록 도울 수 있다.'].mean()
survey_before_efficacy_mean_value_23 = survey_before_efficacy['23. 피드백 수용자의 창의력을 향상시킬 수 있다.'].mean()
survey_before_efficacy_mean_value_24 = survey_before_efficacy['24. 디자인에 어려움을 겪는 피드백 수용자에게 도움을 줄 수 있다.'].mean()

survey_before_efficacy_std_value_1 = survey_before_efficacy['1. 피드백 수용자의 수준을 파악하기 위한 다양한 평가 전략을 사용할 수 있다.'].std()
survey_before_efficacy_std_value_2 = survey_before_efficacy['2. 피드백 수용자가 혼란스러워할 때 대체 설명이나 예시를 제공할 수 있다.'].std()
survey_before_efficacy_std_value_3 = survey_before_efficacy['3. 피드백 수용자를 위한 좋은 질문을 만들 수 있다.'].std()
survey_before_efficacy_std_value_5 = survey_before_efficacy['5. 피드백 수용자의 어려운 질문에 잘 대처 할 수 있다.'].std()
survey_before_efficacy_std_value_6 = survey_before_efficacy['6. 피드백 수용자의 수준에 맞게 피드백을 조정할 수 있다.'].std()
survey_before_efficacy_std_value_7 = survey_before_efficacy['7. 피드백 수용자가 나의 피드백을 얼마나 이해했는지 파악할 수 있다.'].std()
survey_before_efficacy_std_value_8 = survey_before_efficacy['8. 능력이 뛰어난 피드백 수용자에게 적절한 피드백을 제공할 수 있다.'].std()
survey_before_efficacy_std_value_17 = survey_before_efficacy['17. 피드백 수용자가 디자인 잘할 수 있다고 믿게 하기 위해 노력할 수 있다.'].std()
survey_before_efficacy_std_value_18 = survey_before_efficacy['18. 피드백 수용자가 디자인에 가치를 두도록 도울 수 있다.'].std()
survey_before_efficacy_std_value_19 = survey_before_efficacy['19. 디자인에 흥미를 보이지 않는 피드백 수용자에게 동기를 부여할 수 있다.'].std()
survey_before_efficacy_std_value_22 = survey_before_efficacy['22. 피드백 수용자가 비판적으로 사고하도록 도울 수 있다.'].std()
survey_before_efficacy_std_value_23 = survey_before_efficacy['23. 피드백 수용자의 창의력을 향상시킬 수 있다.'].std()
survey_before_efficacy_std_value_24 = survey_before_efficacy['24. 디자인에 어려움을 겪는 피드백 수용자에게 도움을 줄 수 있다.'].std()

# print('mean_value_1:', round(survey_before_efficacy_mean_value_1, 2))
# print('mean_value_2:', round(survey_before_efficacy_mean_value_2, 2))
# print('mean_value_3:', round(survey_before_efficacy_mean_value_3, 2))
# print('mean_value_5:', round(survey_before_efficacy_mean_value_5, 2))
# print('mean_value_6:', round(survey_before_efficacy_mean_value_6, 2))
# print('mean_value_7:', round(survey_before_efficacy_mean_value_7, 2))
# print('mean_value_8:', round(survey_before_efficacy_mean_value_8, 2))
# print('mean_value_17:', round(survey_before_efficacy_mean_value_17, 2))
# print('mean_value_18:', round(survey_before_efficacy_mean_value_18, 2))
# print('mean_value_19:', round(survey_before_efficacy_mean_value_19, 2))
# print('mean_value_22:', round(survey_before_efficacy_mean_value_22, 2))
# print('mean_value_23:', round(survey_before_efficacy_mean_value_23, 2))
# print('mean_value_24:', round(survey_before_efficacy_mean_value_24, 2))

# print('std_value_1:', round(survey_before_efficacy_std_value_1, 3))
# print('std_value_2:', round(survey_before_efficacy_std_value_2, 2))
# print('std_value_3:', round(survey_before_efficacy_std_value_3, 2))
# print('std_value_5:', round(survey_before_efficacy_std_value_5, 2))
# print('std_value_6:', round(survey_before_efficacy_std_value_6, 2))
# print('std_value_7:', round(survey_before_efficacy_std_value_7, 2))
# print('std_value_8:', round(survey_before_efficacy_std_value_8, 2))
# print('std_value_17:', round(survey_before_efficacy_std_value_17, 2))
# print('std_value_18:', round(survey_before_efficacy_std_value_18, 2))
# print('std_value_19:', round(survey_before_efficacy_std_value_19, 2))
# print('std_value_22:', round(survey_before_efficacy_std_value_22, 2))
# print('std_value_23:', round(survey_before_efficacy_std_value_23, 2))
# print('std_value_24:', round(survey_before_efficacy_std_value_24, 2))

# %%
survey_after_efficacy_mean_value_1 = survey_after_efficacy['1. 피드백 수용자의 수준을 파악하기 위한 다양한 평가 전략을 사용할 수 있다.'].mean()
survey_after_efficacy_mean_value_2 = survey_after_efficacy['2. 피드백 수용자가 혼란스러워할 때 대체 설명이나 예시를 제공할 수 있다.'].mean()
survey_after_efficacy_mean_value_3 = survey_after_efficacy['3. 피드백 수용자를 위한 좋은 질문을 만들 수 있다.'].mean()
survey_after_efficacy_mean_value_5 = survey_after_efficacy['5. 피드백 수용자의 어려운 질문에 잘 대처 할 수 있다.'].mean()
survey_after_efficacy_mean_value_6 = survey_after_efficacy['6. 피드백 수용자의 수준에 맞게 피드백을 조정할 수 있다.'].mean()
survey_after_efficacy_mean_value_7 = survey_after_efficacy['7. 피드백 수용자가 나의 피드백을 얼마나 이해했는지 파악할 수 있다.'].mean()
survey_after_efficacy_mean_value_8 = survey_after_efficacy['8. 능력이 뛰어난 피드백 수용자에게 적절한 피드백을 제공할 수 있다.'].mean()
survey_after_efficacy_mean_value_17 = survey_after_efficacy['17. 피드백 수용자가 디자인 잘할 수 있다고 믿게 하기 위해 노력할 수 있다.'].mean()
survey_after_efficacy_mean_value_18 = survey_after_efficacy['18. 피드백 수용자가 디자인에 가치를 두도록 도울 수 있다.'].mean()
survey_after_efficacy_mean_value_19 = survey_after_efficacy['19. 디자인에 흥미를 보이지 않는 피드백 수용자에게 동기를 부여할 수 있다.'].mean()
survey_after_efficacy_mean_value_22 = survey_after_efficacy['22. 피드백 수용자가 비판적으로 사고하도록 도울 수 있다.'].mean()
survey_after_efficacy_mean_value_23 = survey_after_efficacy['23. 피드백 수용자의 창의력을 향상시킬 수 있다.'].mean()
survey_after_efficacy_mean_value_24 = survey_after_efficacy['24. 디자인에 어려움을 겪는 피드백 수용자에게 도움을 줄 수 있다.'].mean()

survey_after_efficacy_std_value_1 = survey_after_efficacy['1. 피드백 수용자의 수준을 파악하기 위한 다양한 평가 전략을 사용할 수 있다.'].std()
survey_after_efficacy_std_value_2 = survey_after_efficacy['2. 피드백 수용자가 혼란스러워할 때 대체 설명이나 예시를 제공할 수 있다.'].std()
survey_after_efficacy_std_value_3 = survey_after_efficacy['3. 피드백 수용자를 위한 좋은 질문을 만들 수 있다.'].std()
survey_after_efficacy_std_value_5 = survey_after_efficacy['5. 피드백 수용자의 어려운 질문에 잘 대처 할 수 있다.'].std()
survey_after_efficacy_std_value_6 = survey_after_efficacy['6. 피드백 수용자의 수준에 맞게 피드백을 조정할 수 있다.'].std()
survey_after_efficacy_std_value_7 = survey_after_efficacy['7. 피드백 수용자가 나의 피드백을 얼마나 이해했는지 파악할 수 있다.'].std()
survey_after_efficacy_std_value_8 = survey_after_efficacy['8. 능력이 뛰어난 피드백 수용자에게 적절한 피드백을 제공할 수 있다.'].std()
survey_after_efficacy_std_value_17 = survey_after_efficacy['17. 피드백 수용자가 디자인 잘할 수 있다고 믿게 하기 위해 노력할 수 있다.'].std()
survey_after_efficacy_std_value_18 = survey_after_efficacy['18. 피드백 수용자가 디자인에 가치를 두도록 도울 수 있다.'].std()
survey_after_efficacy_std_value_19 = survey_after_efficacy['19. 디자인에 흥미를 보이지 않는 피드백 수용자에게 동기를 부여할 수 있다.'].std()
survey_after_efficacy_std_value_22 = survey_after_efficacy['22. 피드백 수용자가 비판적으로 사고하도록 도울 수 있다.'].std()
survey_after_efficacy_std_value_23 = survey_after_efficacy['23. 피드백 수용자의 창의력을 향상시킬 수 있다.'].std()
survey_after_efficacy_std_value_24 = survey_after_efficacy['24. 디자인에 어려움을 겪는 피드백 수용자에게 도움을 줄 수 있다.'].std()

# print('mean_value_1:', round(survey_after_efficacy_mean_value_1, 2))
# print('mean_value_2:', round(survey_after_efficacy_mean_value_2, 2))
# print('mean_value_3:', round(survey_after_efficacy_mean_value_3, 2))
# print('mean_value_5:', round(survey_after_efficacy_mean_value_5, 2))
# print('mean_value_6:', round(survey_after_efficacy_mean_value_6, 2))
# print('mean_value_7:', round(survey_after_efficacy_mean_value_7, 2))
# print('mean_value_8:', round(survey_after_efficacy_mean_value_8, 2))
# print('mean_value_17:', round(survey_after_efficacy_mean_value_17, 2))
# print('mean_value_18:', round(survey_after_efficacy_mean_value_18, 2))
# print('mean_value_19:', round(survey_after_efficacy_mean_value_19, 2))
# print('mean_value_22:', round(survey_after_efficacy_mean_value_22, 2))
# print('mean_value_23:', round(survey_after_efficacy_mean_value_23, 2))
# print('mean_value_24:', round(survey_after_efficacy_mean_value_24, 2))

# print('std_value_1:', round(survey_after_efficacy_std_value_1, 2))
# print('std_value_2:', round(survey_after_efficacy_std_value_2, 2))
# print('std_value_3:', round(survey_after_efficacy_std_value_3, 2))
# print('std_value_5:', round(survey_after_efficacy_std_value_5, 2))
# print('std_value_6:', round(survey_after_efficacy_std_value_6, 2))
# print('std_value_7:', round(survey_after_efficacy_std_value_7, 2))
# print('std_value_8:', round(survey_after_efficacy_std_value_8, 2))
# print('std_value_17:', round(survey_after_efficacy_std_value_17, 2))
# print('std_value_18:', round(survey_after_efficacy_std_value_18, 2))
# print('std_value_19:', round(survey_after_efficacy_std_value_19, 2))
# print('std_value_22:', round(survey_after_efficacy_std_value_22, 2))
# print('std_value_23:', round(survey_after_efficacy_std_value_23, 2))
# print('std_value_24:', round(survey_after_efficacy_std_value_24, 2))

# %%
t_stat_1, p_value_1 = stats.ttest_ind(survey_before_efficacy['1. 피드백 수용자의 수준을 파악하기 위한 다양한 평가 전략을 사용할 수 있다.'], survey_after_efficacy['1. 피드백 수용자의 수준을 파악하기 위한 다양한 평가 전략을 사용할 수 있다.'])
t_stat_2, p_value_2 = stats.ttest_ind(survey_before_efficacy['2. 피드백 수용자가 혼란스러워할 때 대체 설명이나 예시를 제공할 수 있다.'], survey_after_efficacy['2. 피드백 수용자가 혼란스러워할 때 대체 설명이나 예시를 제공할 수 있다.'])
t_stat_3, p_value_3 = stats.ttest_ind(survey_before_efficacy['3. 피드백 수용자를 위한 좋은 질문을 만들 수 있다.'], survey_after_efficacy['3. 피드백 수용자를 위한 좋은 질문을 만들 수 있다.'])
t_stat_5, p_value_5 = stats.ttest_ind(survey_before_efficacy['5. 피드백 수용자의 어려운 질문에 잘 대처 할 수 있다.'], survey_after_efficacy['5. 피드백 수용자의 어려운 질문에 잘 대처 할 수 있다.'])
t_stat_6, p_value_6 = stats.ttest_ind(survey_before_efficacy['6. 피드백 수용자의 수준에 맞게 피드백을 조정할 수 있다.'], survey_after_efficacy['6. 피드백 수용자의 수준에 맞게 피드백을 조정할 수 있다.'])
t_stat_7, p_value_7 = stats.ttest_ind(survey_before_efficacy['7. 피드백 수용자가 나의 피드백을 얼마나 이해했는지 파악할 수 있다.'], survey_after_efficacy['7. 피드백 수용자가 나의 피드백을 얼마나 이해했는지 파악할 수 있다.'])
t_stat_8, p_value_8 = stats.ttest_ind(survey_before_efficacy['8. 능력이 뛰어난 피드백 수용자에게 적절한 피드백을 제공할 수 있다.'], survey_after_efficacy['8. 능력이 뛰어난 피드백 수용자에게 적절한 피드백을 제공할 수 있다.'])
t_stat_17, p_value_17 = stats.ttest_ind(survey_before_efficacy['17. 피드백 수용자가 디자인 잘할 수 있다고 믿게 하기 위해 노력할 수 있다.'], survey_after_efficacy['17. 피드백 수용자가 디자인 잘할 수 있다고 믿게 하기 위해 노력할 수 있다.'])
t_stat_18, p_value_18 = stats.ttest_ind(survey_before_efficacy['18. 피드백 수용자가 디자인에 가치를 두도록 도울 수 있다.'], survey_after_efficacy['18. 피드백 수용자가 디자인에 가치를 두도록 도울 수 있다.'])
t_stat_19, p_value_19 = stats.ttest_ind(survey_before_efficacy['19. 디자인에 흥미를 보이지 않는 피드백 수용자에게 동기를 부여할 수 있다.'], survey_after_efficacy['19. 디자인에 흥미를 보이지 않는 피드백 수용자에게 동기를 부여할 수 있다.'])
t_stat_22, p_value_22 = stats.ttest_ind(survey_before_efficacy['22. 피드백 수용자가 비판적으로 사고하도록 도울 수 있다.'], survey_after_efficacy['22. 피드백 수용자가 비판적으로 사고하도록 도울 수 있다.'])
t_stat_23, p_value_23 = stats.ttest_ind(survey_before_efficacy['23. 피드백 수용자의 창의력을 향상시킬 수 있다.'], survey_after_efficacy['23. 피드백 수용자의 창의력을 향상시킬 수 있다.'])
t_stat_24, p_value_24 = stats.ttest_ind(survey_before_efficacy['24. 디자인에 어려움을 겪는 피드백 수용자에게 도움을 줄 수 있다.'], survey_after_efficacy['24. 디자인에 어려움을 겪는 피드백 수용자에게 도움을 줄 수 있다.'])

# print('t_stat_1', t_stat_1)
print('p_value_1', round(p_value_1 * 13,4))
print('p_value_2', round(p_value_2 * 13,4))
print('p_value_3', round(p_value_3 * 13,4))
print('p_value_5', round(p_value_5 * 13,4))
print('p_value_6', round(p_value_6 * 13,4))
print('p_value_7', round(p_value_7 * 13,4))
print('p_value_8', round(p_value_8 * 13,4))
print('p_value_17', round(p_value_17 * 13,4))
print('p_value_18', round(p_value_18 * 13,4))
print('p_value_19', round(p_value_19 * 13,4))
print('p_value_22', round(p_value_22 * 13,4))
print('p_value_23', round(p_value_23 * 13,4))
print('p_value_24', round(p_value_24 * 13,4))
# Out:
# p_value_1 0.0063
# p_value_2 2.2192
# p_value_3 0.0
# p_value_5 0.0038
# p_value_6 0.8272
# p_value_7 0.0241
# p_value_8 0.7608
# p_value_17 7.0246
# p_value_18 0.1141
# p_value_19 1.163
# p_value_22 0.2565
# p_value_23 0.3897
# p_value_24 1.979

# %%
survey_baseline_mean_value_1 = survey_baseline['해당 시스템을 통해 아이디어를 피드백 하는 것이 재미있었다. '].mean()
survey_baseline_mean_value_2 = survey_baseline['해당 시스템을 통해 아이디어를 피드백 하는 것은 쉬웠다.'].mean()
survey_baseline_mean_value_3 = survey_baseline['앞으로도 해당 시스템을 통해 피드백을 연습하고 싶다.'].mean()
survey_baseline_mean_value_4 = survey_baseline['해당 시스템의 사용하여 피드백 하는 것은 많은 인지부하(cognitive load)를 필요로 했다.'].mean()
survey_baseline_mean_value_5 = survey_baseline['해당 시스템을 통해 디자인 아이디어의 피드백을 주는 것이 실제 디자인 아이디어의 피드백을 주는 경험과 유사하다.'].mean()
survey_baseline_mean_value_6 = survey_baseline['해당 시스템의 학생(멘티)은 실제 디자인과 학생 같았다.'].mean()
survey_baseline_mean_value_7 = survey_baseline['해당 시스템에서 학생(멘티)와의 대화가 기존에 생각지 못한 피드백을 떠올리도록 영감을 주었다.'].mean()
survey_baseline_mean_value_8 = survey_baseline['해당 시스템이 내가 피드백을 잘 제공하고 있는지 인지하는데 도움이 되었다.'].mean()
survey_baseline_mean_value_9 = survey_baseline['나의 피드백을 통해 학생(멘티)의 아이디어가 개선되었다.'].mean()
survey_baseline_mean_value_10 = survey_baseline['해당 시스템을 사용하고 나의 피드백 제공 실력이 향상되었다.'].mean()

survey_baseline_std_value_1 = survey_baseline['해당 시스템을 통해 아이디어를 피드백 하는 것이 재미있었다. '].std()
survey_baseline_std_value_2 = survey_baseline['해당 시스템을 통해 아이디어를 피드백 하는 것은 쉬웠다.'].std()
survey_baseline_std_value_3 = survey_baseline['앞으로도 해당 시스템을 통해 피드백을 연습하고 싶다.'].std()
survey_baseline_std_value_4 = survey_baseline['해당 시스템의 사용하여 피드백 하는 것은 많은 인지부하(cognitive load)를 필요로 했다.'].std()
survey_baseline_std_value_5 = survey_baseline['해당 시스템을 통해 디자인 아이디어의 피드백을 주는 것이 실제 디자인 아이디어의 피드백을 주는 경험과 유사하다.'].std()
survey_baseline_std_value_6 = survey_baseline['해당 시스템의 학생(멘티)은 실제 디자인과 학생 같았다.'].std()
survey_baseline_std_value_7 = survey_baseline['해당 시스템에서 학생(멘티)와의 대화가 기존에 생각지 못한 피드백을 떠올리도록 영감을 주었다.'].std()
survey_baseline_std_value_8 = survey_baseline['해당 시스템이 내가 피드백을 잘 제공하고 있는지 인지하는데 도움이 되었다.'].std()
survey_baseline_std_value_9 = survey_baseline['나의 피드백을 통해 학생(멘티)의 아이디어가 개선되었다.'].std()
survey_baseline_std_value_10 = survey_baseline['해당 시스템을 사용하고 나의 피드백 제공 실력이 향상되었다.'].std()

# print('mean_value_1:', round(survey_baseline_mean_value_1, 2))
# print('mean_value_2:', round(survey_baseline_mean_value_2, 2))
# print('mean_value_3:', round(survey_baseline_mean_value_3, 2))
# print('mean_value_4:', round(survey_baseline_mean_value_4, 2))
# print('mean_value_5:', round(survey_baseline_mean_value_5, 2))
# print('mean_value_6:', round(survey_baseline_mean_value_6, 2))
# print('mean_value_7:', round(survey_baseline_mean_value_7, 2))
# print('mean_value_8:', round(survey_baseline_mean_value_8, 2))
# print('mean_value_9:', round(survey_baseline_mean_value_9, 2))
# print('mean_value_10:', round(survey_baseline_mean_value_10, 2))

# print('std_value_1:', round(survey_baseline_std_value_1, 2))
# print('std_value_2:', round(survey_baseline_std_value_2, 2))
# print('std_value_3:', round(survey_baseline_std_value_3, 2))
# print('std_value_4:', round(survey_baseline_std_value_4, 2))
# print('std_value_5:', round(survey_baseline_std_value_5, 2))
# print('std_value_6:', round(survey_baseline_std_value_6, 2))
# print('std_value_7:', round(survey_baseline_std_value_7, 2))
# print('std_value_8:', round(survey_baseline_std_value_8, 2))
# print('std_value_9:', round(survey_baseline_std_value_9, 2))
# print('std_value_10:', round(survey_baseline_std_value_10, 2))

# %%
survey_intervention_mean_value_1 = survey_intervention['해당 시스템을 통해 아이디어를 피드백 하는 것이 재미있었다. '].mean()
survey_intervention_mean_value_2 = survey_intervention['해당 시스템을 통해 아이디어를 피드백 하는 것은 쉬웠다.'].mean()
survey_intervention_mean_value_3 = survey_intervention['앞으로도 해당 시스템을 통해 피드백을 연습하고 싶다.'].mean()
survey_intervention_mean_value_4 = survey_intervention['해당 시스템의 사용하여 피드백 하는 것은 많은 인지부하(cognitive load)를 필요로 했다.'].mean()
survey_intervention_mean_value_5 = survey_intervention['해당 시스템을 통해 디자인 아이디어의 피드백을 주는 것이 실제 디자인 아이디어의 피드백을 주는 경험과 유사하다.'].mean()
survey_intervention_mean_value_6 = survey_intervention['해당 시스템의 학생(멘티)은 실제 디자인과 학생 같았다.'].mean()
survey_intervention_mean_value_7 = survey_intervention['해당 시스템에서 학생(멘티)와의 대화가 기존에 생각지 못한 피드백을 떠올리도록 영감을 주었다.'].mean()
survey_intervention_mean_value_8 = survey_intervention['해당 시스템이 내가 피드백을 잘 제공하고 있는지 인지하는데 도움이 되었다.'].mean()
survey_intervention_mean_value_9 = survey_intervention['나의 피드백을 통해 학생(멘티)의 아이디어가 개선되었다.'].mean()
survey_intervention_mean_value_10 = survey_intervention['해당 시스템을 사용하고 나의 피드백 제공 실력이 향상되었다.'].mean()

survey_intervention_std_value_1 = survey_intervention['해당 시스템을 통해 아이디어를 피드백 하는 것이 재미있었다. '].std()
survey_intervention_std_value_2 = survey_intervention['해당 시스템을 통해 아이디어를 피드백 하는 것은 쉬웠다.'].std()
survey_intervention_std_value_3 = survey_intervention['앞으로도 해당 시스템을 통해 피드백을 연습하고 싶다.'].std()
survey_intervention_std_value_4 = survey_intervention['해당 시스템의 사용하여 피드백 하는 것은 많은 인지부하(cognitive load)를 필요로 했다.'].std()
survey_intervention_std_value_5 = survey_intervention['해당 시스템을 통해 디자인 아이디어의 피드백을 주는 것이 실제 디자인 아이디어의 피드백을 주는 경험과 유사하다.'].std()
survey_intervention_std_value_6 = survey_intervention['해당 시스템의 학생(멘티)은 실제 디자인과 학생 같았다.'].std()
survey_intervention_std_value_7 = survey_intervention['해당 시스템에서 학생(멘티)와의 대화가 기존에 생각지 못한 피드백을 떠올리도록 영감을 주었다.'].std()
survey_intervention_std_value_8 = survey_intervention['해당 시스템이 내가 피드백을 잘 제공하고 있는지 인지하는데 도움이 되었다.'].std()
survey_intervention_std_value_9 = survey_intervention['나의 피드백을 통해 학생(멘티)의 아이디어가 개선되었다.'].std()
survey_intervention_std_value_10 = survey_intervention['해당 시스템을 사용하고 나의 피드백 제공 실력이 향상되었다.'].std()

# print('mean_value_1:', round(survey_intervention_mean_value_1, 2))
# print('mean_value_2:', round(survey_intervention_mean_value_2, 2))
# print('mean_value_3:', round(survey_intervention_mean_value_3, 2))
# print('mean_value_4:', round(survey_intervention_mean_value_4, 2))
# print('mean_value_5:', round(survey_intervention_mean_value_5, 2))
# print('mean_value_6:', round(survey_intervention_mean_value_6, 2))
# print('mean_value_7:', round(survey_intervention_mean_value_7, 2))
# print('mean_value_8:', round(survey_intervention_mean_value_8, 2))
# print('mean_value_9:', round(survey_intervention_mean_value_9, 2))
# print('mean_value_10:', round(survey_intervention_mean_value_10, 2))

# print('std_value_1:', round(survey_intervention_std_value_1, 2))
# print('std_value_2:', round(survey_intervention_std_value_2, 2))
# print('std_value_3:', round(survey_intervention_std_value_3, 2))
# print('std_value_4:', round(survey_intervention_std_value_4, 2))
# print('std_value_5:', round(survey_intervention_std_value_5, 2))
# print('std_value_6:', round(survey_intervention_std_value_6, 2))
# print('std_value_7:', round(survey_intervention_std_value_7, 2))
# print('std_value_8:', round(survey_intervention_std_value_8, 2))
# print('std_value_9:', round(survey_intervention_std_value_9, 2))
# print('std_value_10:', round(survey_intervention_std_value_10, 2))

# %%
t_stat_1, p_value_1 = stats.ttest_ind(survey_baseline['해당 시스템을 통해 아이디어를 피드백 하는 것이 재미있었다. '], survey_intervention['해당 시스템을 통해 아이디어를 피드백 하는 것이 재미있었다. '])
t_stat_2, p_value_2 = stats.ttest_ind(survey_baseline['해당 시스템을 통해 아이디어를 피드백 하는 것은 쉬웠다.'], survey_intervention['해당 시스템을 통해 아이디어를 피드백 하는 것은 쉬웠다.'])
t_stat_3, p_value_3 = stats.ttest_ind(survey_baseline['앞으로도 해당 시스템을 통해 피드백을 연습하고 싶다.'], survey_intervention['앞으로도 해당 시스템을 통해 피드백을 연습하고 싶다.'])
t_stat_4, p_value_4 = stats.ttest_ind(survey_baseline['해당 시스템의 사용하여 피드백 하는 것은 많은 인지부하(cognitive load)를 필요로 했다.'], survey_intervention['해당 시스템의 사용하여 피드백 하는 것은 많은 인지부하(cognitive load)를 필요로 했다.'])
t_stat_5, p_value_5 = stats.ttest_ind(survey_baseline['해당 시스템을 통해 디자인 아이디어의 피드백을 주는 것이 실제 디자인 아이디어의 피드백을 주는 경험과 유사하다.'], survey_intervention['해당 시스템을 통해 디자인 아이디어의 피드백을 주는 것이 실제 디자인 아이디어의 피드백을 주는 경험과 유사하다.'])
t_stat_6, p_value_6 = stats.ttest_ind(survey_baseline['해당 시스템의 학생(멘티)은 실제 디자인과 학생 같았다.'], survey_intervention['해당 시스템의 학생(멘티)은 실제 디자인과 학생 같았다.'])
t_stat_7, p_value_7 = stats.ttest_ind(survey_baseline['해당 시스템에서 학생(멘티)와의 대화가 기존에 생각지 못한 피드백을 떠올리도록 영감을 주었다.'], survey_intervention['해당 시스템에서 학생(멘티)와의 대화가 기존에 생각지 못한 피드백을 떠올리도록 영감을 주었다.'])
t_stat_8, p_value_8 = stats.ttest_ind(survey_baseline['해당 시스템이 내가 피드백을 잘 제공하고 있는지 인지하는데 도움이 되었다.'], survey_intervention['해당 시스템이 내가 피드백을 잘 제공하고 있는지 인지하는데 도움이 되었다.'])
t_stat_9, p_value_9 = stats.ttest_ind(survey_baseline['나의 피드백을 통해 학생(멘티)의 아이디어가 개선되었다.'], survey_intervention['나의 피드백을 통해 학생(멘티)의 아이디어가 개선되었다.'])
t_stat_10, p_value_10 = stats.ttest_ind(survey_baseline['해당 시스템을 사용하고 나의 피드백 제공 실력이 향상되었다.'], survey_intervention['해당 시스템을 사용하고 나의 피드백 제공 실력이 향상되었다.'])

# print('t_stat_1', t_stat_1)
# print('p_value_1', round(p_value_1,4))
# print('p_value_2', round(p_value_2,4))
# print('p_value_3', round(p_value_3,4))
# print('p_value_4', round(p_value_4,4))
# print('p_value_5', round(p_value_5,4))
# print('p_value_6', round(p_value_6,4))
# print('p_value_7', round(p_value_7,4))
# print('p_value_8', round(p_value_8,4))
# print('p_value_9', round(p_value_9,4))
# print('p_value_10', round(p_value_10,4))

# %%
p1_base = pd.read_csv('logdata_edit/P1_base.csv', encoding='utf-8')
p2_base = pd.read_csv('logdata_edit/P2_base.csv', encoding='utf-8')
p3_base = pd.read_csv('logdata_edit/P3_base.csv', encoding='utf-8')
p4_base = pd.read_csv('logdata_edit/P4_base.csv', encoding='utf-8')
p5_base = pd.read_csv('logdata_edit/P5_base.csv', encoding='utf-8')
p6_base = pd.read_csv('logdata_edit/P6_base.csv', encoding='utf-8')
p7_base = pd.read_csv('logdata_edit/P7_base.csv', encoding='utf-8')
p8_base = pd.read_csv('logdata_edit/P8_base.csv', encoding='utf-8')
p9_base = pd.read_csv('logdata_edit/P9_base.csv', encoding='utf-8')
p10_base = pd.read_csv('logdata_edit/P10_base.csv', encoding='utf-8')
p11_base = pd.read_csv('logdata_edit/P11_base.csv', encoding='utf-8')
p12_base = pd.read_csv('logdata_edit/P12_base.csv', encoding='utf-8')
p13_base = pd.read_csv('logdata_edit/P13_base.csv', encoding='utf-8')
p14_base = pd.read_csv('logdata_edit/P14_base.csv', encoding='utf-8')
p15_base = pd.read_csv('logdata_edit/P15_base.csv', encoding='utf-8')
p16_base = pd.read_csv('logdata_edit/P16_base.csv', encoding='utf-8')
p17_base = pd.read_csv('logdata_edit/P17_base.csv', encoding='utf-8')
p18_base = pd.read_csv('logdata_edit/P18_base.csv', encoding='utf-8')
p19_base = pd.read_csv('logdata_edit/P19_base.csv', encoding='utf-8')
p20_base = pd.read_csv('logdata_edit/P20_base.csv', encoding='utf-8')
p21_base = pd.read_csv('logdata_edit/P21_base.csv', encoding='utf-8')
p22_base = pd.read_csv('logdata_edit/P22_base.csv', encoding='utf-8')
p23_base = pd.read_csv('logdata_edit/P23_base.csv', encoding='utf-8')
p24_base = pd.read_csv('logdata_edit/P24_base.csv', encoding='utf-8')

p1_base
# Out:
#     user_id           timestamp             tag  \
# 0         1  2024-08-12 6:31:38           start
# 1         1  2024-08-12 6:32:38  user_feedaback
# 2         1  2024-08-12 6:33:08  user_feedaback
# 3         1  2024-08-12 6:33:34  user_feedaback
# 4         1  2024-08-12 6:34:47  user_feedaback
# 5         1  2024-08-12 6:35:12  user_feedaback
# 6         1  2024-08-12 6:35:42  user_feedaback
# 7         1  2024-08-12 6:36:30  user_feedaback
# 8         1  2024-08-12 6:37:20  user_feedaback
# 9         1  2024-08-12 6:38:19  user_feedaback
# 10        1  2024-08-12 6:38:56  user_feedaback
# 11        1  2024-08-12 6:39:31  user_feedaback
# 12        1  2024-08-12 6:40:02     update_idea
# 13        1  2024-08-12 6:40:35  user_feedaback
# 14        1  2024-08-12 6:41:08  user_feedaback
# 15        1  2024-08-12 6:41:49  user_feedaback
# 16        1  2024-08-12 6:42:40  user_feedaback
# 17        1  2024-08-12 6:43:07  user_feedaback
# ...

# %%
p1_inter = pd.read_csv('logdata_edit/P1_inter.csv', encoding='utf-8')
p2_inter = pd.read_csv('logdata_edit/P2_inter.csv', encoding='utf-8')
p3_inter = pd.read_csv('logdata_edit/P3_inter.csv', encoding='utf-8')
p4_inter = pd.read_csv('logdata_edit/P4_inter.csv', encoding='utf-8')
p5_inter = pd.read_csv('logdata_edit/P5_inter.csv', encoding='utf-8')
p6_inter = pd.read_csv('logdata_edit/P6_inter.csv', encoding='utf-8')
p7_inter = pd.read_csv('logdata_edit/P7_inter.csv', encoding='utf-8')
p8_inter = pd.read_csv('logdata_edit/P8_inter.csv', encoding='utf-8')
p9_inter = pd.read_csv('logdata_edit/P9_inter.csv', encoding='utf-8')
p10_inter = pd.read_csv('logdata_edit/P10_inter.csv', encoding='utf-8')
p11_inter = pd.read_csv('logdata_edit/P11_inter.csv', encoding='utf-8')
p12_inter = pd.read_csv('logdata_edit/P12_inter.csv', encoding='utf-8')
p13_inter = pd.read_csv('logdata_edit/P13_inter.csv', encoding='utf-8')
p14_inter = pd.read_csv('logdata_edit/P14_inter.csv', encoding='utf-8')
p15_inter = pd.read_csv('logdata_edit/P15_inter.csv', encoding='utf-8')
p16_inter = pd.read_csv('logdata_edit/P16_inter.csv', encoding='utf-8')
p17_inter = pd.read_csv('logdata_edit/P17_inter.csv', encoding='utf-8')
p18_inter = pd.read_csv('logdata_edit/P18_inter.csv', encoding='utf-8')
p19_inter = pd.read_csv('logdata_edit/P19_inter.csv', encoding='utf-8')
p20_inter = pd.read_csv('logdata_edit/P20_inter.csv', encoding='utf-8')
p21_inter = pd.read_csv('logdata_edit/P21_inter.csv', encoding='utf-8')
p22_inter = pd.read_csv('logdata_edit/P22_inter.csv', encoding='utf-8')
p23_inter = pd.read_csv('logdata_edit/P23_inter.csv', encoding='utf-8')
p24_inter = pd.read_csv('logdata_edit/P24_inter.csv', encoding='utf-8')

# %%
base_feedback = []

base_feedback.append((p1_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p2_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p3_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p4_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p5_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p6_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p7_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p8_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p9_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p10_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p11_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p12_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p13_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p14_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p15_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p16_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p17_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p18_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p19_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p20_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p21_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p22_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p23_base['tag'] == 'user_feedaback').sum())
base_feedback.append((p24_base['tag'] == 'user_feedaback').sum())

# %%
inter_feedback = []

inter_feedback.append((p1_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p2_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p3_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p4_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p5_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p6_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p7_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p8_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p9_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p10_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p11_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p12_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p13_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p14_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p15_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p16_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p17_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p18_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p19_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p20_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p21_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p22_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p23_inter['tag'] == 'user_feedaback').sum())
inter_feedback.append((p24_inter['tag'] == 'user_feedaback').sum())

# %%
inter_question = []

inter_question.append((p1_inter['tag'] == 'student_question').sum())
inter_question.append((p2_inter['tag'] == 'student_question').sum())
inter_question.append((p3_inter['tag'] == 'student_question').sum())
inter_question.append((p4_inter['tag'] == 'student_question').sum())
inter_question.append((p5_inter['tag'] == 'student_question').sum())
inter_question.append((p6_inter['tag'] == 'student_question').sum())
inter_question.append((p7_inter['tag'] == 'student_question').sum())
inter_question.append((p8_inter['tag'] == 'student_question').sum())
inter_question.append((p9_inter['tag'] == 'student_question').sum())
inter_question.append((p10_inter['tag'] == 'student_question').sum())
inter_question.append((p11_inter['tag'] == 'student_question').sum())
inter_question.append((p12_inter['tag'] == 'student_question').sum())
inter_question.append((p13_inter['tag'] == 'student_question').sum())
inter_question.append((p14_inter['tag'] == 'student_question').sum())
inter_question.append((p15_inter['tag'] == 'student_question').sum())
inter_question.append((p16_inter['tag'] == 'student_question').sum())
inter_question.append((p17_inter['tag'] == 'student_question').sum())
inter_question.append((p18_inter['tag'] == 'student_question').sum())
inter_question.append((p19_inter['tag'] == 'student_question').sum())
inter_question.append((p20_inter['tag'] == 'student_question').sum())
inter_question.append((p21_inter['tag'] == 'student_question').sum())
inter_question.append((p22_inter['tag'] == 'student_question').sum())
inter_question.append((p23_inter['tag'] == 'student_question').sum())
inter_question.append((p24_inter['tag'] == 'student_question').sum())

# %%
base_update_idea = []

base_update_idea.append((p1_base['tag'] == 'update_idea').sum())
base_update_idea.append((p2_base['tag'] == 'update_idea').sum())
base_update_idea.append((p3_base['tag'] == 'update_idea').sum())
base_update_idea.append((p4_base['tag'] == 'update_idea').sum())
base_update_idea.append((p5_base['tag'] == 'update_idea').sum())
base_update_idea.append((p6_base['tag'] == 'update_idea').sum())
base_update_idea.append((p7_base['tag'] == 'update_idea').sum())
base_update_idea.append((p8_base['tag'] == 'update_idea').sum())
base_update_idea.append((p9_base['tag'] == 'update_idea').sum())
base_update_idea.append((p10_base['tag'] == 'update_idea').sum())
base_update_idea.append((p11_base['tag'] == 'update_idea').sum())
base_update_idea.append((p12_base['tag'] == 'update_idea').sum())
base_update_idea.append((p13_base['tag'] == 'update_idea').sum())
base_update_idea.append((p14_base['tag'] == 'update_idea').sum())
base_update_idea.append((p15_base['tag'] == 'update_idea').sum())
base_update_idea.append((p16_base['tag'] == 'update_idea').sum())
base_update_idea.append((p17_base['tag'] == 'update_idea').sum())
base_update_idea.append((p18_base['tag'] == 'update_idea').sum())
base_update_idea.append((p19_base['tag'] == 'update_idea').sum())
base_update_idea.append((p20_base['tag'] == 'update_idea').sum())
base_update_idea.append((p21_base['tag'] == 'update_idea').sum())
base_update_idea.append((p22_base['tag'] == 'update_idea').sum())
base_update_idea.append((p23_base['tag'] == 'update_idea').sum())
base_update_idea.append((p24_base['tag'] == 'update_idea').sum())

# %%
inter_update_idea = []

inter_update_idea.append((p1_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p2_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p3_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p4_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p5_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p6_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p7_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p8_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p9_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p10_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p11_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p12_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p13_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p14_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p15_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p16_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p17_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p18_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p19_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p20_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p21_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p22_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p23_inter['tag'] == 'update_idea').sum())
inter_update_idea.append((p24_inter['tag'] == 'update_idea').sum())

# %%
feedback_num = pd.DataFrame({'base': base_feedback, 'inter': inter_feedback})
question_num = pd.DataFrame({'inter_question': inter_question})
update_idea_num = pd.DataFrame({'base': base_update_idea, 'inter': inter_update_idea})

base_feedback_mean = feedback_num['base'].mean()
base_feedback_std = feedback_num['base'].std()
inter_feedback_mean = feedback_num['inter'].mean()
inter_feedback_std = feedback_num['inter'].std()
inter_question_mean = question_num['inter_question'].mean()
inter_question_std = question_num['inter_question'].std()
base_update_idea_mean = update_idea_num['base'].mean()
base_update_idea_std = update_idea_num['base'].std()
inter_update_idea_mean = update_idea_num['inter'].mean()
inter_update_idea_std = update_idea_num['inter'].std()

t_stat_feedback_num, p_value_feedback_num = stats.ttest_ind(feedback_num['base'], feedback_num['inter'])
t_stat_update_idea_num, p_value_update_idea_num = stats.ttest_ind(update_idea_num['base'], update_idea_num['inter'])


print("base_mean: ", base_feedback_mean)
print("base_std: ", base_feedback_std)
print("inter_mean: ", inter_feedback_mean)
print("inter_std: ", inter_feedback_std)
print("t_stat:", t_stat_feedback_num)
print("p_value:", p_value_feedback_num)

print("question_mean", inter_question_mean)
print("question_std", inter_question_std)

print("base_update_idea_mean: ", base_update_idea_mean)
print("base_update_idea_std: ", base_update_idea_std)
print("inter_update_idea_mean: ", inter_update_idea_mean)
print("inter_update_idea_std: ", inter_update_idea_std)
print("t_stat_update_idea:", t_stat_update_idea_num)
print("p_value_update_idea:", p_value_update_idea_num)
# Out:
# base_mean:  14.291666666666666
# base_std:  6.603550867372116
# inter_mean:  12.625
# inter_std:  4.147419312840425
# t_stat: 1.0470661366353464
# p_value: 0.300539843885519
# question_mean 3.7916666666666665
# question_std 1.1025333147551268
# base_update_idea_mean:  2.9166666666666665
# base_update_idea_std:  1.5580552724098262
# inter_update_idea_mean:  2.625
# inter_update_idea_std:  1.0555237727226274
# t_stat_update_idea: 0.7592566023652962
# p_value_update_idea: 0.4515724582829975

# %%
def convert_input_only(data):
    rawdf = data[data['tag'] == 'user_feedaback']
    
    if isinstance(rawdf['data'].iloc[0], str):
        rawdf.loc[:, 'data'] = rawdf['data'].apply(json.loads)

    df = json_normalize(rawdf['data'])

    df = df[['user_input']]
    df['length'] = df['user_input'].apply(len)
    df.insert(0, 'user_id', data['user_id'])
    df.insert(1, 'timestamp', data['timestamp'])
    
    return df

base_input = convert_input_only(p1_base)
base_input = base_input.append(convert_input_only(p2_base))
base_input = base_input.append(convert_input_only(p3_base))
base_input = base_input.append(convert_input_only(p4_base))
base_input = base_input.append(convert_input_only(p5_base))
base_input = base_input.append(convert_input_only(p6_base))
base_input = base_input.append(convert_input_only(p7_base))
base_input = base_input.append(convert_input_only(p8_base))
base_input = base_input.append(convert_input_only(p9_base))
base_input = base_input.append(convert_input_only(p10_base))
base_input = base_input.append(convert_input_only(p11_base))
base_input = base_input.append(convert_input_only(p12_base))
base_input = base_input.append(convert_input_only(p13_base))
base_input = base_input.append(convert_input_only(p14_base))
base_input = base_input.append(convert_input_only(p15_base))
base_input = base_input.append(convert_input_only(p16_base))
base_input = base_input.append(convert_input_only(p17_base))
base_input = base_input.append(convert_input_only(p18_base))
base_input = base_input.append(convert_input_only(p19_base))
base_input = base_input.append(convert_input_only(p10_base))
base_input = base_input.append(convert_input_only(p20_base))
base_input = base_input.append(convert_input_only(p21_base))
base_input = base_input.append(convert_input_only(p22_base))
base_input = base_input.append(convert_input_only(p23_base))
base_input = base_input.append(convert_input_only(p24_base))
# Out:
# /var/folders/yl/ylpr_wks0yq8n6566ks9wnb80000gn/T/ipykernel_32863/491459919.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdf.loc[:, 'data'] = rawdf['data'].apply(json.loads)
# /var/folders/yl/ylpr_wks0yq8n6566ks9wnb80000gn/T/ipykernel_32863/491459919.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdf.loc[:, 'data'] = rawdf['data'].apply(json.loads)
# ...

# %%
inter_input = convert_input_only(p1_inter)
inter_input = inter_input.append(convert_input_only(p2_inter))
inter_input = inter_input.append(convert_input_only(p3_inter))
inter_input = inter_input.append(convert_input_only(p4_inter))
inter_input = inter_input.append(convert_input_only(p5_inter))
inter_input = inter_input.append(convert_input_only(p6_inter))
inter_input = inter_input.append(convert_input_only(p7_inter))
inter_input = inter_input.append(convert_input_only(p8_inter))
inter_input = inter_input.append(convert_input_only(p9_inter))
inter_input = inter_input.append(convert_input_only(p10_inter))
inter_input = inter_input.append(convert_input_only(p11_inter))
inter_input = inter_input.append(convert_input_only(p12_inter))
inter_input = inter_input.append(convert_input_only(p13_inter))
inter_input = inter_input.append(convert_input_only(p14_inter))
inter_input = inter_input.append(convert_input_only(p15_inter))
inter_input = inter_input.append(convert_input_only(p16_inter))
inter_input = inter_input.append(convert_input_only(p17_inter))
inter_input = inter_input.append(convert_input_only(p18_inter))
inter_input = inter_input.append(convert_input_only(p19_inter))
inter_input = inter_input.append(convert_input_only(p10_inter))
inter_input = inter_input.append(convert_input_only(p20_inter))
inter_input = inter_input.append(convert_input_only(p21_inter))
inter_input = inter_input.append(convert_input_only(p22_inter))
inter_input = inter_input.append(convert_input_only(p23_inter))
inter_input = inter_input.append(convert_input_only(p24_inter))
# Out:
# /var/folders/yl/ylpr_wks0yq8n6566ks9wnb80000gn/T/ipykernel_32863/491459919.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdf.loc[:, 'data'] = rawdf['data'].apply(json.loads)
# /var/folders/yl/ylpr_wks0yq8n6566ks9wnb80000gn/T/ipykernel_32863/491459919.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdf.loc[:, 'data'] = rawdf['data'].apply(json.loads)
# ...

# %%
base_input['length'].mean()
base_input['length'].std()
inter_input['length'].mean()
inter_input['length'].std()

t_stat_feedback_length, p_value_feedback_length = stats.ttest_ind(base_input['length'], inter_input['length'])

print("base_length_mean: ", base_input['length'].mean())
print("base_length_std: ", base_input['length'].std())
print("inter_length_mean: ", inter_input['length'].mean())
print("inter_length_std: ", inter_input['length'].std())
print("t_stat:", t_stat_feedback_length)
print("p_value:", p_value_feedback_length)

print(len(base_input))
print(len(inter_input))
# Out:
# base_length_mean:  90.00280112044818
# base_length_std:  67.64337659095732
# inter_length_mean:  102.03809523809524
# inter_length_std:  66.84933013153902
# t_stat: -2.3143257139278606
# p_value: 0.020951393126235247
# 357
# 315

# %%
def convert(data):
    
    rawdf = data[data['tag'] == 'user_feedaback']
    
    if isinstance(rawdf['data'].iloc[0], str):
        rawdf.loc[:, 'data'] = rawdf['data'].apply(json.loads)

    df = json_normalize(rawdf['data'], record_path=['evaluation', 'sentences'])
    columns = [
        'sentence', 'categories', 'type', 'evaluation.timely', 'evaluation.relevance', 
        'evaluation.high-level', 'evaluation.specificity', 'evaluation.justification', 
        'evaluation.active', 'evaluation.sentiment'
    ]

    # DataFrame에서 필요한 컬럼이 있는지 확인하고, 없으면 추가
    for col in columns:
        if col not in df.columns:
            df[col] = pd.NA  # 또는 None, '', 0 등 원하는 기본값으로 설정

    # 이제 안전하게 컬럼을 선택할 수 있음
    df = df[columns]
    df.insert(0, 'user_id', data['user_id'])
    df.insert(1, 'timestamp', data['timestamp'])
    
    return df

p1_base_convert = convert(p1_base)
p2_base_convert = convert(p2_base)
p3_base_convert = convert(p3_base)
p4_base_convert = convert(p4_base)
p5_base_convert = convert(p5_base)
p6_base_convert = convert(p6_base)
p7_base_convert = convert(p7_base)
p8_base_convert = convert(p8_base)
p9_base_convert = convert(p9_base)
p10_base_convert = convert(p10_base)
p11_base_convert = convert(p11_base)
p12_base_convert = convert(p12_base)
p13_base_convert = convert(p13_base)
p14_base_convert = convert(p14_base)
p15_base_convert = convert(p15_base)
p16_base_convert = convert(p16_base)
p17_base_convert = convert(p17_base)
p18_base_convert = convert(p18_base)
p19_base_convert = convert(p19_base)
p20_base_convert = convert(p20_base)
p21_base_convert = convert(p21_base)
p22_base_convert = convert(p22_base)
p23_base_convert = convert(p23_base)
p24_base_convert = convert(p24_base)

# p1_base_convert
# Out:
# /var/folders/yl/ylpr_wks0yq8n6566ks9wnb80000gn/T/ipykernel_32863/869704736.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdf.loc[:, 'data'] = rawdf['data'].apply(json.loads)
# /var/folders/yl/ylpr_wks0yq8n6566ks9wnb80000gn/T/ipykernel_32863/869704736.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdf.loc[:, 'data'] = rawdf['data'].apply(json.loads)
# /var/folders/yl/ylpr_wks0yq8n6566ks9wnb80000gn/T/ipykernel_32863/869704736.py:6: SettingWithCopyWarning:
# ...

# %%
p1_inter_convert = convert(p1_inter)
p2_inter_convert = convert(p2_inter)
p3_inter_convert = convert(p3_inter)
p4_inter_convert = convert(p4_inter)
p5_inter_convert = convert(p5_inter)
p6_inter_convert = convert(p6_inter)
p7_inter_convert = convert(p7_inter)
p8_inter_convert = convert(p8_inter)
p9_inter_convert = convert(p9_inter)
p10_inter_convert = convert(p10_inter)
p11_inter_convert = convert(p11_inter)
p12_inter_convert = convert(p12_inter)
p13_inter_convert = convert(p13_inter)
p14_inter_convert = convert(p14_inter)
p15_inter_convert = convert(p15_inter)
p16_inter_convert = convert(p16_inter)
p17_inter_convert = convert(p17_inter)
p18_inter_convert = convert(p18_inter)
p19_inter_convert = convert(p19_inter)
p20_inter_convert = convert(p20_inter)
p21_inter_convert = convert(p21_inter)
p22_inter_convert = convert(p22_inter)
p23_inter_convert = convert(p23_inter)
p24_inter_convert = convert(p24_inter)
# Out:
# /var/folders/yl/ylpr_wks0yq8n6566ks9wnb80000gn/T/ipykernel_32863/869704736.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdf.loc[:, 'data'] = rawdf['data'].apply(json.loads)
# /var/folders/yl/ylpr_wks0yq8n6566ks9wnb80000gn/T/ipykernel_32863/869704736.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdf.loc[:, 'data'] = rawdf['data'].apply(json.loads)
# /var/folders/yl/ylpr_wks0yq8n6566ks9wnb80000gn/T/ipykernel_32863/869704736.py:6: SettingWithCopyWarning:
# ...

# %%
base_feedback_convert = []

base_feedback_convert.append(len(p1_base_convert))
base_feedback_convert.append(len(p2_base_convert))
base_feedback_convert.append(len(p3_base_convert))
base_feedback_convert.append(len(p4_base_convert))
base_feedback_convert.append(len(p5_base_convert))
base_feedback_convert.append(len(p6_base_convert))
base_feedback_convert.append(len(p7_base_convert))
base_feedback_convert.append(len(p8_base_convert))
base_feedback_convert.append(len(p9_base_convert))
base_feedback_convert.append(len(p10_base_convert))
base_feedback_convert.append(len(p11_base_convert))
base_feedback_convert.append(len(p12_base_convert))
base_feedback_convert.append(len(p13_base_convert))
base_feedback_convert.append(len(p14_base_convert))
base_feedback_convert.append(len(p15_base_convert))
base_feedback_convert.append(len(p16_base_convert))
base_feedback_convert.append(len(p17_base_convert))
base_feedback_convert.append(len(p18_base_convert))
base_feedback_convert.append(len(p19_base_convert))
base_feedback_convert.append(len(p20_base_convert))
base_feedback_convert.append(len(p21_base_convert))
base_feedback_convert.append(len(p22_base_convert))
base_feedback_convert.append(len(p23_base_convert))
base_feedback_convert.append(len(p24_base_convert))

# %%
inter_feedback_convert = []

inter_feedback_convert.append(len(p1_inter_convert))
inter_feedback_convert.append(len(p2_inter_convert))
inter_feedback_convert.append(len(p3_inter_convert))
inter_feedback_convert.append(len(p4_inter_convert))
inter_feedback_convert.append(len(p5_inter_convert))
inter_feedback_convert.append(len(p6_inter_convert))
inter_feedback_convert.append(len(p7_inter_convert))
inter_feedback_convert.append(len(p8_inter_convert))
inter_feedback_convert.append(len(p9_inter_convert))
inter_feedback_convert.append(len(p10_inter_convert))
inter_feedback_convert.append(len(p11_inter_convert))
inter_feedback_convert.append(len(p12_inter_convert))
inter_feedback_convert.append(len(p13_inter_convert))
inter_feedback_convert.append(len(p14_inter_convert))
inter_feedback_convert.append(len(p15_inter_convert))
inter_feedback_convert.append(len(p16_inter_convert))
inter_feedback_convert.append(len(p17_inter_convert))
inter_feedback_convert.append(len(p18_inter_convert))
inter_feedback_convert.append(len(p19_inter_convert))
inter_feedback_convert.append(len(p20_inter_convert))
inter_feedback_convert.append(len(p21_inter_convert))
inter_feedback_convert.append(len(p22_inter_convert))
inter_feedback_convert.append(len(p23_inter_convert))
inter_feedback_convert.append(len(p24_inter_convert))

# %%
feedback_convert_num = pd.DataFrame({'base': base_feedback_convert, 'inter': inter_feedback_convert})


base_feedback_convert_mean = feedback_convert_num['base'].mean()
base_feedback_convert_std = feedback_convert_num['base'].std()
inter_feedback_convert_mean = feedback_convert_num['inter'].mean()
inter_feedback_convert_std = feedback_convert_num['inter'].std()


t_stat_feedback_convert_num, p_value_feedback_convert_num = stats.ttest_ind(feedback_convert_num['base'], feedback_convert_num['inter'])

print("base_mean: ", base_feedback_convert_mean)
print("base_std: ", base_feedback_convert_std)
print("inter_mean: ", inter_feedback_convert_mean)
print("inter_std: ", inter_feedback_convert_std)
print("t_stat:", t_stat_feedback_convert_num)
print("p_value:", p_value_feedback_convert_num)
# Out:
# base_mean:  29.458333333333332
# base_std:  9.537017885320733
# inter_mean:  28.291666666666668
# inter_std:  6.537378590886388
# t_stat: 0.494310292339614
# p_value: 0.6234395169710236

# %%
base_convert = pd.concat([
    p1_base_convert, 
    p2_base_convert,
    p3_base_convert,
    p4_base_convert, 
    p5_base_convert,
    p6_base_convert,
    p7_base_convert, 
    p8_base_convert,
    p9_base_convert,
    p10_base_convert, 
    p11_base_convert,
    p12_base_convert,
    p13_base_convert, 
    p14_base_convert,
    p15_base_convert,
    p16_base_convert, 
    p17_base_convert,
    p18_base_convert,
    p19_base_convert, 
    p20_base_convert,
    p21_base_convert,
    p22_base_convert,
    p23_base_convert,
    p24_base_convert
    ], ignore_index=True)

base_convert.to_csv('baseline_feedback_sentence.csv', index=False)

# %%
inter_convert = pd.concat([
    p1_inter_convert, 
    p2_inter_convert,
    p3_inter_convert,
    p4_inter_convert, 
    p5_inter_convert,
    p6_inter_convert,
    p7_inter_convert, 
    p8_inter_convert,
    p9_inter_convert,
    p10_inter_convert, 
    p11_inter_convert,
    p12_inter_convert,
    p13_inter_convert, 
    p14_inter_convert,
    p15_inter_convert,
    p16_inter_convert, 
    p17_inter_convert,
    p18_inter_convert,
    p19_inter_convert, 
    p20_inter_convert,
    p21_inter_convert,
    p22_inter_convert,
    p23_inter_convert,
    p24_inter_convert
    ], ignore_index=True)

inter_convert.to_csv('intervention_feedback_sentence.csv', index=False)

# %%
inter_convert_counts = inter_convert['type'].value_counts()
len(base_convert)
# Out:
# 707

# %%
def getMeanStdP(val):
    print("base_mean:", base_convert.dropna()[val].mean())
    print("base_std:", base_convert.dropna()[val].std())
    print("inter_mean:", inter_convert.dropna()[val].mean())
    print("inter_std:", inter_convert.dropna()[val].std())
    
    t_stat, p_value = stats.ttest_ind(base_convert.dropna()[val], inter_convert.dropna()[val])
    print("P:", p_value)

# getMeanStdP('evaluation.timely')
# print("")
# getMeanStdP('evaluation.relevance')
# print("")
# getMeanStdP('evaluation.high-level')
# print("")
# getMeanStdP('evaluation.specificity')
# print("")
# getMeanStdP('evaluation.justification')
# print("")
# getMeanStdP('evaluation.active')
# print("")
getMeanStdP('evaluation.sentiment')
# Out:
# base_mean: 0.04484304932735426
# base_std: 0.40017771675251296
# inter_mean: 0.13380281690140844
# inter_std: 0.38090733854755904
# P: 0.03559089157836547

# %%
def getMeanStdP(val):
    print("base_mean:", base_convert[base_convert[val] != 0].dropna()[val].mean())
    print("base_std:", base_convert[base_convert[val] != 0].dropna()[val].std())
    print("inter_mean:", inter_convert[inter_convert[val] != 0].dropna()[val].mean())
    print("inter_std:", inter_convert[inter_convert[val] != 0].dropna()[val].std())
    
    t_stat, p_value = stats.ttest_ind(base_convert[base_convert[val] != 0].dropna()[val], inter_convert[inter_convert[val] != 0].dropna()[val])
    print("P:", p_value)

getMeanStdP('evaluation.timely')
print("")
getMeanStdP('evaluation.relevance')
print("")
getMeanStdP('evaluation.high-level')
print("")
getMeanStdP('evaluation.specificity')
print("")
getMeanStdP('evaluation.justification')
print("")
getMeanStdP('evaluation.active')
# Out:
# base_mean: 5.2513089005235605
# base_std: 0.5709510660886203
# inter_mean: 5.082644628099174
# inter_std: 0.791483594897415
# P: 0.029805658029359753
#
# base_mean: 5.557291666666667
# base_std: 0.9851509881530797
# inter_mean: 5.2727272727272725
# inter_std: 1.2449899597988732
# P: 0.025567337706335867
#
# base_mean: 3.3
# base_std: 1.7636842150969112
# inter_mean: 3.15702479338843
# inter_std: 1.8120350643351693
# P: 0.4909685687661737
#
# base_mean: 5.303030303030303
# base_std: 0.5294365215047319
# inter_mean: 5.333333333333333
# inter_std: 0.7302967433402214
# P: 0.8604653156926902
#
# base_mean: 5.151515151515151
# base_std: 0.6185270871803091
# inter_mean: 4.904761904761905
# inter_std: 0.9952267030562386
# P: 0.2653695355419
#
# base_mean: 4.8
# base_std: 0.9247553264475439
# inter_mean: 4.619047619047619
# inter_std: 1.4654757069358222
# P: 0.5910541638783228
